# %% [markdown]
# ***3.1 Warming Up Exercises - Basic Inspection and Exploration:***
# ***Problem 1 - Data Read, Write and Inspect:***

# %% [markdown]
# **Complete all following Task:**
#
# ***• Dataset for the Task: "bank.csv"***
#
# ***1.Load the provided dataset and import in pandas DataFrame.***

# %%
import pandas as pd

df = pd.read_csv("drive/MyDrive/Dataset/bank.csv")
print(df)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ***2.Check info of the DataFrame and identify following:***
#
# **(a) columns with dtypes=object**
#
# **(b) unique values of those columns.**
#
# **(c) check for the total number of null values in each column.**

# %%
import pandas as pd

df = pd.read_csv("drive/MyDrive/Dataset/bank.csv")

# 1. Check info of the DataFrame
print("(2) DataFrame Info:")
print(df.info())
print("\n")

# 2. Identify columns with dtype=object
object_cols = df.select_dtypes(include='object').columns
print("(a) Columns with dtype=object:")
print(object_cols)
print("\n")

# 3. Unique values of object columns
print("(b) Unique values in object columns:")
for col in object_cols:
    print(f"{col}: {df[col].unique()}")
print("\n")

# 4. Total number of null values in each column
print("(c) Total number of null values in each column:")
print(df.isnull().sum())
# Out:
# (2) DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
#
#
# ...

# %% [markdown]
# ***3. Drop all the columns with dtypes object and store in new DataFrame, also write the DataFrame in".csv" with name "banknumericdata.csv".***

# %%
df = pd.read_csv("drive/MyDrive/Dataset/bank.csv")
numeric_df = df.select_dtypes(exclude='object')
numeric_df.to_csv("banknumericdata.csv", index=False)

# %% [markdown]
# ***4. Read "banknumericdata.csv" and Find the summary statistics.***

# %%
df = pd.read_csv("banknumericdata.csv")
summary_stats = df.describe()
print(summary_stats)
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ***Problem 2 - Data Imputations:***
#
# **Complete all the following Task:**

# %% [markdown]
# ***• Dataset for the Task: "medical_student.csv"***
#
# ***1. Load the provided dataset and import in pandas DataFrame***.

# %%
df = pd.read_csv("drive/MyDrive/Dataset/medical_students_dataset.csv")
print(df)
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %% [markdown]
# ***2. Check info of the DataFrame and identify column with missing (null) values.***

# %%
df.info()
df_missing_values = df.isnull().sum()
print(df_missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# ...

# %% [markdown]
# ***3. For the column with missing values fill the values using various techniques we discussed above and try
# to explain why did you select the particular methods for particular column.***

# %%
import pandas as pd


# NUMERIC COLUMNS
df = pd.read_csv("drive/MyDrive/Dataset/medical_students_dataset.csv")
df["Student ID"] = df.index + 1
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Height'] = df['Height'].fillna(df['Height'].median())
df['Weight'] = df['Weight'].fillna(df['Weight'].median())
df['BMI'] = df['BMI'].fillna(df['BMI'].median())
print("For Numeric columns")
print("For numeric columns like Age, Height, Weight, and BMI, we used Median because these values often contain outliers and are not normally distributed. Median is robust to extreme values and provides a realistic central value.")

df['Temperature'] = df['Temperature'].fillna(df['Temperature'].mean())
df['Heart Rate'] = df['Heart Rate'].fillna(df['Heart Rate'].mean())
df['Blood Pressure'] = df['Blood Pressure'].fillna(df['Blood Pressure'].mean())
df['Cholesterol'] = df['Cholesterol'].fillna(df['Cholesterol'].mean())
print("For medical measurements such as Temperature, Blood Pressure, Heart Rate, and Cholesterol, we used Mean, because these variables follow a normal distribution, and the mean accurately represents the natural average")

# CATEGORICAL COLUMNS
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Blood Type'] = df['Blood Type'].fillna(df['Blood Type'].mode()[0])
df['Diabetes'] = df['Diabetes'].fillna(df['Diabetes'].mode()[0])
df['Smoking'] = df['Smoking'].fillna(df['Smoking'].mode()[0])
print("For categorical columns")
print("For categorical columns like Gender, Blood Type, Diabetes, and Smoking, we used Mode, which fills missing values with the most common category, maintaining consistent class distribution.")

print(df.isnull().sum())
# Out:
# For Numeric columns
# For numeric columns like Age, Height, Weight, and BMI, we used Median because these values often contain outliers and are not normally distributed. Median is robust to extreme values and provides a realistic central value.
# For medical measurements such as Temperature, Blood Pressure, Heart Rate, and Cholesterol, we used Mean, because these variables follow a normal distribution, and the mean accurately represents the natural average
# For categorical columns
# For categorical columns like Gender, Blood Type, Diabetes, and Smoking, we used Mode, which fills missing values with the most common category, maintaining consistent class distribution.
# Student ID        0
# Age               0
# Gender            0
# Height            0
# Weight            0
# Blood Type        0
# BMI               0
# Temperature       0
# Heart Rate        0
# Blood Pressure    0
# Cholesterol       0
# Diabetes          0
# Smoking           0
# dtype: int64

# %% [markdown]
# **4.** ***Check for any duplicate values present in Dataset and do necessary to manage the duplicate items.***
# {Hint: dataset.duplicated.sum()}**bold text**

# %%
df.duplicated().sum()
df[df.duplicated()]
df.drop_duplicates(inplace=True)

# %% [markdown]
# ***3.2 Exercises - Data Cleaning and Transformations with ”Titanic Dataset”:***

# %% [markdown]
# ***Problem - 1:***
#
# Create a DataFrame that is subsetted for the columns ’Name’, ’Pclass’, ’Sex’, ’Age’, ’Fare’, and ’Survived’.
# Retain only those rows where ’Pclass’ is equal to 1, representing first-class passengers . What is the mean,
# median, maximum value, and minimum value of the ’Fare’ column?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("drive/MyDrive/Dataset/Titanic-Dataset.csv")   # change file name if needed

# 1. Create subset DataFrame
subset_df = df[['Name', 'Pclass', 'Sex', 'Age', 'Fare', 'Survived']]

# 2. Keep only first-class passengers (Pclass = 1)
first_class_df = subset_df[subset_df['Pclass'] == 1]

# 3. Calculate required statistics of Fare
mean_fare = first_class_df['Fare'].mean()
median_fare = first_class_df['Fare'].median()
max_fare = first_class_df['Fare'].max()
min_fare = first_class_df['Fare'].min()

# 4. Print results
print("Mean Fare:", mean_fare)
print("Median Fare:", median_fare)
print("Maximum Fare:", max_fare)
print("Minimum Fare:", min_fare)
# Out:
# Mean Fare: 84.1546875
# Median Fare: 60.287499999999994
# Maximum Fare: 512.3292
# Minimum Fare: 0.0

# %% [markdown]
# ***Problem - 2***:
# How many null values are contained in the ’Age’ column in your subsetted DataFrame? Once you’ve found
# this out, drop them from your DataFrame.

# %%
# Count how many null values are in the 'Age' column
null_age_count = df['Age'].isna().sum()
print("Number of null values in Age column:", null_age_count)

# Drop all rows where 'Age' is null
df = df.dropna(subset=['Age'])

# Verify the null values are removed
print("Null values in Age column after dropping:", df['Age'].isna().sum())

# Show first few rows to confirm DataFrame is clean
print(df.head())
# Out:
# Number of null values in Age column: 177
# Null values in Age column after dropping: 0
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ***Problem - 3:***
#
#
# The ’Embarked’ column in the Titanic dataset contains categorical data representing the ports of embarka-
# tion:
#
# • ’C’ for Cherbourg
#
# • ’Q’ for Queenstown
#
# • ’S’ for Southampton

# %% [markdown]
# ***Task:***
# ***1. Use one-hot encoding to convert the ’Embarked’ column into separate binary columns*** (’Embarked C’,
# ’Embarked Q’, ’Embarked S’).

# %%
embarked_dummies = pd.get_dummies(df['Embarked'], prefix='Embarked')

# %% [markdown]
# ***2. Add these new columns to the original DataFrame.***

# %%
df = pd.concat([df, embarked_dummies], axis=1)

# %% [markdown]
# ***3. Drop the original ’Embarked’ column.***

# %%
df = df.drop('Embarked', axis=1)

# %% [markdown]
# ***4. Print the first few rows of the modified DataFrame to verify the changes.***

# %%
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN       False       False        True
# 1      0          PC 17599  71.2833   C85        True       False       False
# 2      0  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %% [markdown]
# ***Problem - 4:***
#
#
# Compare the mean survival rates (’Survived’) for the different groups in the ’Sex’ column. Draw a visual-
# ization to show how the survival distributions vary by gender.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Compute mean survival rate by gender
mean_survival = df.groupby('Sex')['Survived'].mean()
print("Mean survival rate by gender:")
print(mean_survival)

# Plot the mean survival rates
plt.figure(figsize=(6,4))
mean_survival.plot(kind='bar', color=['skyblue', 'pink'])
plt.xlabel("Sex")
plt.ylabel("Mean Survival Rate")
plt.title("Mean Survival Rate by Gender")
plt.ylim(0, 1)
plt.xticks(rotation=0)
plt.show()
# Out:
# Mean survival rate by gender:
# Sex
# female    0.754789
# male      0.205298
# Name: Survived, dtype: float64

# %% [markdown]
# ***Problem - 5:***
#
# Draw a visualization that breaks your visualization from Exercise 3 down by the port of embarkation (’Em-
# barked’). In this instance, compare the ports ’C’ (Cherbourg), ’Q’ (Queenstown), and ’S’ (Southampton).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
df = pd.read_csv("drive/MyDrive/Dataset/Titanic-Dataset.csv")

# Filter for the three ports
ports = ['C', 'Q', 'S']
df_ports = df[df['Embarked'].isin(ports)]

# Example: Visualizing survival rate by Embarked
sns.set(style="whitegrid")

plt.figure(figsize=(8,6))
sns.countplot(data=df_ports, x='Embarked', hue='Survived', palette='Set2')
plt.title('Survival Count by Port of Embarkation')
plt.xlabel('Port of Embarkation')
plt.ylabel('Number of Passengers')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ***Problem - 6***{***Optional***}:
#
# Show how the survival rates (’Survived’) vary by age group and passenger class (’Pclass’). Break up the
# ’Age’ column into five quantiles in your DataFrame, and then compare the means of ’Survived’ by class
# and age group. Draw a visualization using a any plotting library to represent this graphically.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
df = pd.read_csv("drive/MyDrive/Dataset/Titanic-Dataset.csv")

# Drop rows where Age is missing
df = df.dropna(subset=['Age'])

# Create 5 quantiles for Age
df['AgeGroup'] = pd.qcut(df['Age'], 5, labels=['Q1','Q2','Q3','Q4','Q5'])

# Calculate mean survival by Pclass and AgeGroup
survival_rates = df.groupby(['Pclass','AgeGroup'])['Survived'].mean().reset_index()

# Visualize
plt.figure(figsize=(10,6))
sns.barplot(data=survival_rates, x='AgeGroup', y='Survived', hue='Pclass', palette='Set1')
plt.title('Survival Rate by Age Group and Passenger Class')
plt.ylabel('Mean Survival Rate')
plt.xlabel('Age Group (Quantiles)')
plt.legend(title='Passenger Class')
plt.show()
# Out:
# /tmp/ipython-input-322720079.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rates = df.groupby(['Pclass','AgeGroup'])['Survived'].mean().reset_index()
